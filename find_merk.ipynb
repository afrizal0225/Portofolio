# %%
import pandas as pd

# %%
df1 = pd.read_excel(r'C:\Users\afriz\Documents\Pekerjaan\YENS\analisa merk food\Stock_2_22.xlsx')
df2 = pd.read_excel(r'C:\Users\afriz\Documents\Pekerjaan\YENS\analisa merk food\Stock_3_22.xlsx')
df3 = pd.read_excel(r'C:\Users\afriz\Documents\Pekerjaan\YENS\analisa merk food\Stock_4_22.xlsx')

# %%
df1.head(20)
# Out:
#                     BO Yens     Unnamed: 1     Unnamed: 2  \
# 0             Laporan Stock            NaN            NaN
# 1   2022-02-01 - 2022-02-28            NaN            NaN
# 2            Lokasi : Y-STB            NaN            NaN
# 3                       NaN            NaN            NaN
# 4               Kode Barang        Barcode        Artikel
# 5                   0100048        0100048       P601TLST
# 6                   0105723        0105723        0105723
# 7                   0105813  8997033370014  8997033370014
# 8                   0105836  8997002900013  8997002900013
# 9                   0105857  8997002900075  8997002900075
# 10                  0105858  6281073210143  6281073210143
# 11                  0105859  6281073210181  6281073210181
# 12                  0105860  8001430111030  8001430111030
# 13                  0150166  8993430166137  8993430166137
# 14                  0150399  4987176000552  4987176000552
# ...

# %%
# Cleaning Data

df1.columns = df1.iloc[4]
df2.columns = df2.iloc[4]
df3.columns = df3.iloc[4]

df1 = df1.drop(df1.index[0:5])
df2 = df2.drop(df2.index[0:5])
df3 = df3.drop(df3.index[0:5])

df1 = df1[:-1]
df2 = df2[:-1]
df3 = df3[:-1]

# %%
df_all = pd.concat([df1,df2,df3])

# %%
df_all.head()
# Out:
# 4 Kode Barang        Barcode        Artikel           Nama Barang  \
# 5     0100048        0100048       P601TLST       INTERLAC SACHET
# 6     0105723        0105723        0105723              LACTASIP
# 7     0105813  8997033370014  8997033370014   INNOCARE NON PARFUM
# 8     0105836  8997002900013  8997002900013  AL JAZIRA SRKRM 360G
# 9     0105857  8997002900075  8997002900075  AL JZR PRM SRKRM 360
#
# 4 Keterangan Barang Input Barang              Supplier Input Supplier  \
# 5          INTERLAC   2020-09-05  MENSA BINA SUKSES PT     2020-09-05
# 6          LACTASIP   2020-09-05       LINA COOLER BAG     2020-09-07
# 7          INNOCARE   2020-09-05     BERKAH MANDIRI CV     2020-09-07
# 8                AL   2020-09-05     BERKAH MANDIRI CV     2020-09-07
# 9                AL   2020-09-05     BERKAH MANDIRI CV     2020-09-07
#
# 4 Sub Dept             Kelompok  ... Stock In Stock Out Penjualan Stock Akhir  \
# ...

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4275 entries, 5 to 1429
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Kode Barang          4275 non-null   object
#  1   Barcode              4275 non-null   object
#  2   Artikel              4275 non-null   object
#  3   Nama Barang          4275 non-null   object
#  4   Keterangan Barang    4275 non-null   object
#  5   Input Barang         4275 non-null   object
#  6   Supplier             4275 non-null   object
#  7   Input Supplier       4275 non-null   object
#  8   Sub Dept             4275 non-null   object
#  9   Kelompok             4275 non-null   object
#  10  Stock Awal           4275 non-null   object
#  11  Stock In             4275 non-null   object
#  12  Stock Out            4275 non-null   object
#  13  Penjualan            4275 non-null   object
#  14  Stock Akhir          4275 non-null   object
# ...

# %% [markdown]
# ### From this data where has been cleaned, the EDA processed use Ms. excel and turn into this form

# %% [markdown]
# ![image.png](attachment:image.png)
